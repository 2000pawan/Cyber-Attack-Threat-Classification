# %% [markdown]
# ## Cyber Attack Threat Classification using Machine Learning.

# %%
# Import Important Library that used in data preprocessing and model Training.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.feature_selection import f_classif,SelectKBest
from sklearn.metrics import accuracy_score,precision_score,recall_score,classification_report,f1_score,confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
# Import all csv file.
df=pd.read_csv('MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')         
df1=pd.read_csv('MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')    
df2=pd.read_csv('MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv')          
df3=pd.read_csv('MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv')
df4=pd.read_csv('MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
df5=pd.read_csv('MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
df6=pd.read_csv('MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv')
df7=pd.read_csv('MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv')

# %%
print(df.shape)
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
print(df6.shape)
print(df7.shape)
# Out:
# (225745, 79)
# (286467, 79)
# (191033, 79)
# (529918, 79)
# (288602, 79)
# (170366, 79)
# (445909, 79)
# (692703, 79)

# %%
# Type of Attacks.

print(df[' Label'].unique())
print(df1[' Label'].unique())
print(df2[' Label'].unique())
print(df3[' Label'].unique())
print(df4[' Label'].unique())
print(df5[' Label'].unique())
print(df6[' Label'].unique())
print(df7[' Label'].unique())
# Out:
# ['BENIGN' 'DDoS']
# ['BENIGN' 'PortScan']
# ['BENIGN' 'Bot']
# ['BENIGN']
# ['BENIGN' 'Infiltration']
# ['BENIGN' 'Web Attack � Brute Force' 'Web Attack � XSS'
#  'Web Attack � Sql Injection']
# ['BENIGN' 'FTP-Patator' 'SSH-Patator']
# ['BENIGN' 'DoS slowloris' 'DoS Slowhttptest' 'DoS Hulk' 'DoS GoldenEye'
#  'Heartbleed']

# %%
# Function to fix encoding 
def fix_encoding(text):
    if isinstance(text, str):
        return text.encode('utf-8', 'ignore').decode('utf-8')  # Remove bad characters
    return text

# Apply fix to all DataFrames before merging
dfs = [df, df1, df2, df3, df4, df5, df6, df7]
for i in range(len(dfs)):
    dfs[i][' Label'] = dfs[i][' Label'].apply(fix_encoding)

# Merge all data frame into single dataframe 
merged_df = pd.concat(dfs, ignore_index=True)
merged_df=merged_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Verify df5 labels exist in merged_df
print("Unique labels in merged_df after fix:", merged_df[" Label"].unique())
print(merged_df.shape)

# Export new dataframe.
df1=merged_df.iloc[:200001,:]
df2=merged_df.iloc[200001:,:]
df1.to_csv('cyberattack.csv',index=False)
df2.to_csv('cyberattack1.csv',index=False)
# Out:
# Unique labels in merged_df after fix: ['BENIGN' 'DoS Hulk' 'DDoS' 'PortScan' 'DoS slowloris' 'DoS GoldenEye'
#  'FTP-Patator' 'DoS Slowhttptest' 'Bot' 'SSH-Patator'
#  'Web Attack � Brute Force' 'Web Attack � XSS' 'Heartbleed'
#  'Web Attack � Sql Injection' 'Infiltration']
# (2830743, 79)

# %% [markdown]
# ## EDA--> Exploratory Data Analysis.

# %%
# Import new csv file.
df=pd.read_csv('cyberattack.csv')

# %%
# Knowing Initial Details about Data.

print(df.shape)
print('-----------------------------------------------------------------------------------------------------------------------------------')
print(df.info())
print('-----------------------------------------------------------------------------------------------------------------------------------')
print('Columns Names:- ',list(df.columns))
print('-----------------------------------------------------------------------------------------------------------------------------------')
print(df.describe())
print('-----------------------------------------------------------------------------------------------------------------------------------')
column_name=df.columns
print(column_name)
# Out:
# (200001, 79)
# -----------------------------------------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200001 entries, 0 to 200000
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             200001 non-null  int64
#  1    Flow Duration                200001 non-null  int64
#  2    Total Fwd Packets            200001 non-null  int64
#  3    Total Backward Packets       200001 non-null  int64
#  4   Total Length of Fwd Packets   200001 non-null  int64
#  5    Total Length of Bwd Packets  200001 non-null  int64
#  6    Fwd Packet Length Max        200001 non-null  int64
#  7    Fwd Packet Length Min        200001 non-null  int64
#  8    Fwd Packet Length Mean       200001 non-null  float64
#  9    Fwd Packet Length Std        200001 non-null  float64
#  10  Bwd Packet Length Max         200001 non-null  int64
#  11   Bwd Packet Length Min        200001 non-null  int64
#  12   Bwd Packet Length Mean       200001 non-null  float64
#  13   Bwd Packet Length Std        200001 non-null  float64
#  14  Flow Bytes/s                  199904 non-null  float64
#  15   Flow Packets/s               200001 non-null  float64
#  16   Flow IAT Mean                200001 non-null  float64
#  17   Flow IAT Std                 200001 non-null  float64
#  18   Flow IAT Max                 200001 non-null  int64
#  19   Flow IAT Min                 200001 non-null  int64
#  20  Fwd IAT Total                 200001 non-null  int64
#  21   Fwd IAT Mean                 200001 non-null  float64
#  22   Fwd IAT Std                  200001 non-null  float64
#  23   Fwd IAT Max                  200001 non-null  int64
#  24   Fwd IAT Min                  200001 non-null  int64
#  25  Bwd IAT Total                 200001 non-null  int64
#  26   Bwd IAT Mean                 200001 non-null  float64
#  27   Bwd IAT Std                  200001 non-null  float64
#  28   Bwd IAT Max                  200001 non-null  int64
#  29   Bwd IAT Min                  200001 non-null  int64
#  30  Fwd PSH Flags                 200001 non-null  int64
#  31   Bwd PSH Flags                200001 non-null  int64
#  32   Fwd URG Flags                200001 non-null  int64
#  33   Bwd URG Flags                200001 non-null  int64
#  34   Fwd Header Length            200001 non-null  int64
#  35   Bwd Header Length            200001 non-null  int64
#  36  Fwd Packets/s                 200001 non-null  float64
#  37   Bwd Packets/s                200001 non-null  float64
#  38   Min Packet Length            200001 non-null  int64
#  39   Max Packet Length            200001 non-null  int64
#  40   Packet Length Mean           200001 non-null  float64
#  41   Packet Length Std            200001 non-null  float64
#  42   Packet Length Variance       200001 non-null  float64
#  43  FIN Flag Count                200001 non-null  int64
#  44   SYN Flag Count               200001 non-null  int64
#  45   RST Flag Count               200001 non-null  int64
#  46   PSH Flag Count               200001 non-null  int64
#  47   ACK Flag Count               200001 non-null  int64
#  48   URG Flag Count               200001 non-null  int64
#  49   CWE Flag Count               200001 non-null  int64
#  50   ECE Flag Count               200001 non-null  int64
#  51   Down/Up Ratio                200001 non-null  int64
#  52   Average Packet Size          200001 non-null  float64
#  53   Avg Fwd Segment Size         200001 non-null  float64
#  54   Avg Bwd Segment Size         200001 non-null  float64
#  55   Fwd Header Length.1          200001 non-null  int64
#  56  Fwd Avg Bytes/Bulk            200001 non-null  int64
#  57   Fwd Avg Packets/Bulk         200001 non-null  int64
#  58   Fwd Avg Bulk Rate            200001 non-null  int64
#  59   Bwd Avg Bytes/Bulk           200001 non-null  int64
#  60   Bwd Avg Packets/Bulk         200001 non-null  int64
#  61  Bwd Avg Bulk Rate             200001 non-null  int64
#  62  Subflow Fwd Packets           200001 non-null  int64
#  63   Subflow Fwd Bytes            200001 non-null  int64
#  64   Subflow Bwd Packets          200001 non-null  int64
#  65   Subflow Bwd Bytes            200001 non-null  int64
#  66  Init_Win_bytes_forward        200001 non-null  int64
#  67   Init_Win_bytes_backward      200001 non-null  int64
#  68   act_data_pkt_fwd             200001 non-null  int64
#  69   min_seg_size_forward         200001 non-null  int64
#  70  Active Mean                   200001 non-null  float64
#  71   Active Std                   200001 non-null  float64
#  72   Active Max                   200001 non-null  int64
#  73   Active Min                   200001 non-null  int64
#  74  Idle Mean                     200001 non-null  float64
#  75   Idle Std                     200001 non-null  float64
#  76   Idle Max                     200001 non-null  int64
#  77   Idle Min                     200001 non-null  int64
#  78   Label                        200001 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 120.5+ MB
# None
# -----------------------------------------------------------------------------------------------------------------------------------
# Columns Names:-  [' Destination Port', ' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets', 'Total Length of Fwd Packets', ' Total Length of Bwd Packets', ' Fwd Packet Length Max', ' Fwd Packet Length Min', ' Fwd Packet Length Mean', ' Fwd Packet Length Std', 'Bwd Packet Length Max', ' Bwd Packet Length Min', ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size', ' Avg Fwd Segment Size', ' Avg Bwd Segment Size', ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes', ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward', ' Init_Win_bytes_backward', ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min', ' Label']
# -----------------------------------------------------------------------------------------------------------------------------------
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      200001.000000    2.000010e+05       200001.000000
# mean         8136.750211    1.469667e+07            9.722096
# std         18354.867405    3.355869e+07          777.102954
# min             0.000000   -1.000000e+00            1.000000
# 25%            53.000000    1.540000e+02            2.000000
# 50%            80.000000    3.129300e+04            2.000000
# 75%           443.000000    3.081997e+06            5.000000
# max         65534.000000    1.200000e+08       206687.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count             200001.00000                 2.000010e+05
# mean                  10.96420                 5.377751e+02
# std                 1056.66431                 5.156418e+03
# min                    0.00000                 0.000000e+00
# 25%                    1.00000                 6.000000e+00
# 50%                    2.00000                 6.200000e+01
# 75%                    4.00000                 1.870000e+02
# max               281741.00000                 1.231684e+06
#
#         Total Length of Bwd Packets   Fwd Packet Length Max  \
# count                  2.000010e+05           200001.000000
# mean                   1.701408e+04              207.233229
# std                    2.281053e+06              708.957701
# min                    0.000000e+00                0.000000
# 25%                    0.000000e+00                6.000000
# 50%                    1.220000e+02               37.000000
# 75%                    4.790000e+02               81.000000
# max                    6.070000e+08            24820.000000
#
#         Fwd Packet Length Min   Fwd Packet Length Mean  \
# count           200001.000000            200001.000000
# mean                18.725191                58.322770
# std                 61.058433               186.390328
# min                  0.000000                 0.000000
# 25%                  0.000000                 6.000000
# 50%                  2.000000                34.000000
# 75%                 36.000000                50.000000
# max               2065.000000              4672.000000
#
#         Fwd Packet Length Std  ...   act_data_pkt_fwd   min_seg_size_forward  \
# count           200001.000000  ...      200001.000000          200001.000000
# mean                68.834002  ...           5.649067              26.107749
# std                278.059023  ...         656.006268               6.573265
# min                  0.000000  ...           0.000000               0.000000
# 25%                  0.000000  ...           0.000000              20.000000
# 50%                  0.000000  ...           1.000000              24.000000
# 75%                 26.162951  ...           2.000000              32.000000
# max               6429.190773  ...      198058.000000              78.000000
#
#         Active Mean    Active Std    Active Max    Active Min     Idle Mean  \
# count  2.000010e+05  2.000010e+05  2.000010e+05  2.000010e+05  2.000010e+05
# mean   8.166037e+04  4.146115e+04  1.538393e+05  5.827022e+04  8.254425e+06
# std    6.066633e+05  4.048101e+05  9.980902e+05  5.307162e+05  2.354371e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    7.920000e+07  7.420000e+07  1.050000e+08  7.920000e+07  1.200000e+08
#
#            Idle Std      Idle Max      Idle Min
# count  2.000010e+05  2.000010e+05  2.000010e+05
# mean   4.972929e+05  8.630488e+06  7.863951e+06
# std    4.567078e+06  2.427308e+07  2.328089e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00
# max    7.660000e+07  1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]
# -----------------------------------------------------------------------------------------------------------------------------------
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
#        ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count',
#        ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count',
#        ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count',
#        ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size',
#        ' Avg Fwd Segment Size', ' Avg Bwd Segment Size',
#        ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min',
#        ' Label'],
#       dtype='object')

# %%
# Modifying or Removing Unwanted Data.

df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
print(df.shape)
df = df.replace([np.inf, -np.inf], np.nan).dropna()
print(df.shape)
# Out:
# (191218, 79)
# (191109, 79)

# %%
df[' Label'].unique()
# Out:
# array(['BENIGN', 'DoS Hulk', 'DDoS', 'PortScan', 'DoS slowloris',
#        'DoS GoldenEye', 'FTP-Patator', 'DoS Slowhttptest', 'Bot',
#        'SSH-Patator', 'Web Attack � Brute Force', 'Web Attack � XSS',
#        'Heartbleed', 'Web Attack � Sql Injection', 'Infiltration'],
#       dtype=object)

# %% [markdown]
# ## Visualize Data

# %%
# Data Distribution using Displot

plt.figure(figsize=(10,6))
sns.countplot(x=df[" Label"], palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Distribution of Attack Categories")
plt.xlabel("Attack Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Important Feature Using Sklearn library selectkbest, and f_classify.

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
f_value,p_value=f_classif(X,y)
print(list(f_value))

# Most of the f_value score is greater than 100 so removed those feature which f_value is less than 100.
imp_feature_index=[]
unimp_feature_index=[]
count_imp_feature=0
count_unimp_feature=0
for i,j in enumerate(f_value):
    if j>100:
        count_imp_feature+=1
        imp_feature_index.append(i)
    else:
        count_unimp_feature+=1
        unimp_feature_index.append(i)
        
print('Total Important Feature:- ',count_imp_feature)
print('Total UnImportant Feature:- ',count_unimp_feature)


imp_feature_name=[column_name[i] for i in imp_feature_index]
unimp_feature_name=[column_name[i] for i in unimp_feature_index]
# Out:
# [408.0584559043053, 3843.0618808516974, 0.8244421085258553, 0.37017516267899514, 21.35741585242583, 0.6786384990110117, 154.58708855703247, 291.9590097585697, 149.66438127635433, 122.82230160055417, 16259.555867809744, 1093.662824523422, 16874.461850743, 17102.815662452336, 9.934212722425928, 100.86547278095381, 2148.066972369127, 8001.651104001819, 12693.95168765007, 1022.3192266778492, 3888.982136296016, 1646.6956005810348, 16932.747964902694, 12622.291335073085, 355.91899880990246, 450.3213110643089, 580.5245402075584, 2140.585933927563, 1535.4399291424272, 336.0047830186168, 292.0996343683116, nan, 0.269212869072971, nan, 1.7036030073318993, 0.7143255487857214, 86.71222756340528, 398.4031267241729, 1367.0424399919616, 12771.117007709792, 10961.42813812216, 14104.768853009718, 10560.733697833837, 3770.6969228238845, 292.0996343683116, 0.7761252908054413, 2641.6407336033394, 926.9271745816917, 336.8405349886379, 0.269212869072971, 0.7761252908054413, 333.67236534787224, 11117.228216652506, 149.66438127635433, 16874.46185073972, 1.7036030073318993, nan, nan, nan, nan, nan, nan, 0.8244421085258553, 21.35741585242583, 0.37017516267899514, 0.6788594205686793, 522.8170301462652, 205.89613185478706, 0.13211497187821594, 1533.6030570994517, 1190.6599851002275, 527.7081283614261, 573.0878851994638, 1326.2339023203701, 14129.20144809926, 605.9835204384552, 13154.015554918704, 14232.313446387645]
# Total Important Feature:-  52
# Total UnImportant Feature:-  26

# %% [markdown]
# ## Train Model Using Random Forest with 52 Important Feature.

# %% [markdown]
# ## Data PreProcessing using Standard Scaler and select 52 important feature.

# %%
# Retrive data feature and target
X_new=df.iloc[:,:-1].values
y_new=df.iloc[:,-1].values

# Select K Best Feature
k_best=SelectKBest(f_classif,k=52)
X_best=k_best.fit_transform(X_new,y_new)

# Split Dataset into Two Part.
X_train,X_test,y_train,y_test=train_test_split(X_best,y_new,random_state=1,test_size=0.30)

# Scale the Train and Test Data
sc=StandardScaler()
X_train_new=sc.fit_transform(X_train)
X_test_new=sc.fit_transform(X_test)

# %% [markdown]
# ## Model Train using Random Forest.

# %%
model=RandomForestClassifier(n_estimators=100,random_state=1,bootstrap=True)
model.fit(X_train_new,y_train)
pred_train=model.predict(X_train_new)
pred_test=model.predict(X_test_new)
print('Accuracy Score of Training Data:- ',accuracy_score(y_train,pred_train))
print('Accuracy Score of Testing Data:- ',accuracy_score(y_test,pred_test))
# Out:
# Accuracy Score of Training Data:-  0.9996337160626719
# Accuracy Score of Testing Data:-  0.9114471595765091

# %%
rm=accuracy_score(y_test,pred_test)
cm_train=confusion_matrix(y_train,pred_train)
cm_test=confusion_matrix(y_test,pred_test)
rm
# Out:
# 0.9114471595765091

# %%
print("Classification Report of Training Data:- \n ",classification_report(y_train,pred_train))
print('-----------------------------------------------------------------------------------------------------------------------------------------------')
print('-----------------------------------------------------------------------------------------------------------------------------------------------')
print('-----------------------------------------------------------------------------------------------------------------------------------------------')
print("Classification Report of Testing Data:- \n ",classification_report(y_test,pred_test))
# Out:
# Classification Report of Training Data:-
#                               precision    recall  f1-score   support
#
#                     BENIGN       1.00      1.00      1.00    109524
#                        Bot       1.00      0.97      0.98        90
#                       DDoS       1.00      1.00      1.00      6371
#              DoS GoldenEye       1.00      1.00      1.00       499
#                   DoS Hulk       1.00      1.00      1.00      8794
#           DoS Slowhttptest       1.00      1.00      1.00       259
#              DoS slowloris       1.00      1.00      1.00       286
#                FTP-Patator       1.00      1.00      1.00       342
#                 Heartbleed       1.00      1.00      1.00         2
#               Infiltration       1.00      1.00      1.00         1
#                   PortScan       0.99      1.00      1.00      7331
#                SSH-Patator       1.00      1.00      1.00       191
#   Web Attack � Brute Force       1.00      1.00      1.00        61
# Web Attack � Sql Injection       1.00      1.00      1.00         1
#           Web Attack � XSS       1.00      1.00      1.00        24
#
#                   accuracy                           1.00    133776
#                  macro avg       1.00      1.00      1.00    133776
#               weighted avg       1.00      1.00      1.00    133776
#
# -----------------------------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------------------------------------------
# Classification Report of Testing Data:-
#                             precision    recall  f1-score   support
#
#                   BENIGN       0.90      1.00      0.95     46905
#                      Bot       0.00      0.00      0.00        45
#                     DDoS       1.00      0.62      0.76      2682
#            DoS GoldenEye       1.00      0.88      0.94       229
#                 DoS Hulk       1.00      0.87      0.93      3726
#         DoS Slowhttptest       0.97      0.38      0.54        93
#            DoS slowloris       1.00      0.51      0.67       112
#              FTP-Patator       1.00      0.62      0.77       135
#                 PortScan       0.75      0.00      0.01      3272
#              SSH-Patator       1.00      0.68      0.81        82
# Web Attack � Brute Force       0.00      0.00      0.00        34
#         Web Attack � XSS       0.00      0.00      0.00        18
#
#                 accuracy                           0.91     57333
#                macro avg       0.72      0.46      0.53     57333
#             weighted avg       0.90      0.91      0.88     57333

# %% [markdown]
# ## Visualize Confusion metrics

# %%
# Graph of training Data
label=df[' Label'].unique()
enc=LabelEncoder()
enc.fit_transform(label)
plt.figure(figsize=(8,6))
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", xticklabels=enc.classes_, yticklabels=enc.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# Graph of testing Data
label=df[' Label'].unique()
enc=LabelEncoder()
enc.fit_transform(label)
plt.figure(figsize=(8,6))
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues", xticklabels=enc.classes_, yticklabels=enc.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Model Train using SVM--> Support Vector Machine.

# %%
model1=SVC()
model1.fit(X_train_new,y_train)
pred_train=model1.predict(X_train_new)
pred_test=model1.predict(X_test_new)
print('Accuracy Score of Training Data:- ',accuracy_score(y_train,pred_train))
print('Accuracy Score of Testing Data:- ',accuracy_score(y_test,pred_test))
# Out:
# Accuracy Score of Training Data:-  0.9705328310010765
# Accuracy Score of Testing Data:-  0.9696858702666876

# %%
svm=accuracy_score(y_test,pred_test)
cm1_train=confusion_matrix(y_train,pred_train)
cm1_test=confusion_matrix(y_test,pred_test)

# %%
print("Classification Report of Training Data:- \n",classification_report(y_train,pred_train))
print('-----------------------------------------------------------------------------------------------------------------------------------------------')
print('-----------------------------------------------------------------------------------------------------------------------------------------------')
print('-----------------------------------------------------------------------------------------------------------------------------------------------')
print("Classification Report of Testing Data:- \n",classification_report(y_test,pred_test))
# Out:
# Classification Report of Training Data:-
#                              precision    recall  f1-score   support
#
#                     BENIGN       0.98      0.98      0.98    109524
#                        Bot       1.00      0.01      0.02        90
#                       DDoS       0.99      0.94      0.96      6371
#              DoS GoldenEye       0.98      0.91      0.94       499
#                   DoS Hulk       0.98      0.90      0.94      8794
#           DoS Slowhttptest       0.87      0.95      0.91       259
#              DoS slowloris       0.97      0.85      0.91       286
#                FTP-Patator       1.00      0.49      0.66       342
#                 Heartbleed       1.00      1.00      1.00         2
#               Infiltration       0.00      0.00      0.00         1
#                   PortScan       0.80      0.99      0.89      7331
#                SSH-Patator       1.00      0.01      0.01       191
#   Web Attack � Brute Force       0.00      0.00      0.00        61
# Web Attack � Sql Injection       0.00      0.00      0.00         1
#           Web Attack � XSS       0.00      0.00      0.00        24
#
#                   accuracy                           0.97    133776
#                  macro avg       0.71      0.53      0.55    133776
#               weighted avg       0.97      0.97      0.97    133776
#
# -----------------------------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------------------------------------------
# Classification Report of Testing Data:-
#                            precision    recall  f1-score   support
#
#                   BENIGN       0.98      0.98      0.98     46905
#                      Bot       0.00      0.00      0.00        45
#                     DDoS       0.99      0.93      0.96      2682
#            DoS GoldenEye       0.97      0.90      0.93       229
#                 DoS Hulk       0.98      0.90      0.94      3726
#         DoS Slowhttptest       0.78      0.92      0.85        93
#            DoS slowloris       0.99      0.81      0.89       112
#              FTP-Patator       1.00      0.55      0.71       135
#                 PortScan       0.81      0.99      0.89      3272
#              SSH-Patator       0.00      0.00      0.00        82
# Web Attack � Brute Force       0.00      0.00      0.00        34
#         Web Attack � XSS       0.00      0.00      0.00        18
#
#                 accuracy                           0.97     57333
#                macro avg       0.63      0.58      0.60     57333
#             weighted avg       0.97      0.97      0.97     57333

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=["Random Forest",'SVM'], y=[rm,svm], palette='Blues_r')
plt.title("Accuracy Score of two model")
plt.xlabel("Model")
plt.ylabel("accuracy_score")
plt.show()

# %% [markdown]
# ## Visualize Confusion metrics

# %%
# Graph of training Data
label=df[' Label'].unique()
enc=LabelEncoder()
enc.fit_transform(label)
plt.figure(figsize=(8,6))
sns.heatmap(cm1_train, annot=True, fmt="d", cmap="Blues", xticklabels=enc.classes_, yticklabels=enc.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# Graph of testing Data
label=df[' Label'].unique()
enc=LabelEncoder()
enc.fit_transform(label)
plt.figure(figsize=(8,6))
sns.heatmap(cm1_train, annot=True, fmt="d", cmap="Blues", xticklabels=enc.classes_, yticklabels=enc.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Important features Graph

# %%
plt.figure(figsize=(12,20))
sns.barplot(x=f_value, y=df.columns[:-1], palette='Blues_r')
plt.title("Top 52 Important Features")
plt.xlabel("Feature Importance Score")
plt.ylabel("Feature")
plt.show()

# %%
plt.figure(figsize=(12, 20))
plt.barh(df.columns[:-1], f_value, color='skyblue')
plt.xlabel("Score")
plt.ylabel("Feature Name")
plt.title("Feature Importance")
plt.gca().invert_yaxis()  # To show the highest score at the top
plt.show()

# %%
plt.figure(figsize=(12,20))
plt.scatter(f_value, df.columns[:-1], color='red')
plt.xlabel("Scores")
plt.ylabel("Features")
plt.title("Feature Score Distribution")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Model Testing on Remaining dataset

# %%
df2=pd.read_csv('cyberattack1.csv')

# %%
df3=df2.iloc[:5000:]
df3=df3.replace([np.inf, -np.inf], np.nan).dropna()
print(df3.shape)
x=df3.iloc[:,:-1].values
Y=df3.iloc[:,-1].values
x_best=k_best.transform(x)
x_new=sc.transform(x_best)
# Out:
# (4994, 79)

# %%
# Prediction using Random Forest
pred=model.predict(x_new)
print('Accuracy Score using Random Forest:- ',accuracy_score(Y,pred))
# Out:
# Accuracy Score using Random Forest:-  0.8886663996796156

# %%
# Prediction using SVM
pred1=model1.predict(x_new)
print('Accuracy Score using SVM:- ',accuracy_score(Y,pred1))
# Out:
# Accuracy Score using SVM:-  0.9623548257909491

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=["Random Forest",'SVM'], y=[accuracy_score(Y,pred),accuracy_score(Y,pred1)], palette='Blues_r')
plt.title("Accuracy Score of two model")
plt.xlabel("Model")
plt.ylabel("accuracy_score")
plt.show()
